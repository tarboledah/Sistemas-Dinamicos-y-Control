# %% [markdown]
# <a href="https://colab.research.google.com/github/tarboledah/Sistemas-Dinamicos-y-Control/blob/main/simulacion/Simulaci%C3%B3n_1_SDyControl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install control
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 8.4 MB/s eta 0:00:00
# ...

# %%
# Funciones matemáticas
import numpy as n
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
#definición del sistema
num=[0.3188]
den=[1., 1.143, 0.3188]
ftla= tf(num, den)
print("Funcion de transferencia en LA de la planta: ")
print(ftla)
ftlc=feedback(ftla,1)
print("Funcion de transferencia en lazocerrado: ")
print(ftlc)
# Grafico de polos y ceros del sistema enlazo cerrado.
plt.figure(1, figsize=[7, 4])
pzmap(ftlc)
plt.xlabel("Real")
plt.ylabel("Imaginario")
plt.title("Plano complejo. Polos del sistema en LC")
plt.show(block=False)
# Respuesta escal´on del sistema en LA y LC
plt.figure(2, figsize=[6, 4])
yout, T = step(ftla, T=25)
yout1, T1 = step(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel("tiempo (s)")
plt.ylabel("$y(t)$")
plt.title("Respuesta escalón sistema en LA y LC")
plt.grid()
# Respuesta escal´on del sistema en LA y LC
plt.figure(3, figsize=[6, 4])
yout, T = impulse(ftla, T=25)
yout1, T1 = impulse(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel("tiempo (s)")
plt.ylabel("$y(t)$")
plt.title("Respuesta impulso sistema en LA y LC")
plt.grid()
plt.show()
# Out:
# Funcion de transferencia en LA de la planta:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#         0.3188
# ----------------------
# s^2 + 1.143 s + 0.3188
#
# Funcion de transferencia en lazocerrado:
# <TransferFunction>: sys[2]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#         0.3188
# ----------------------
# s^2 + 1.143 s + 0.6376
# /usr/local/lib/python3.10/dist-packages/control/pzmap.py:318: FutureWarning: pole_zero_plot() return value of poles, zeros is deprecated; use pole_zero_map()
#   warnings.warn(

# %% [markdown]
# SISTEMA MASA-RESORTE-AMORTIGUADO

# %%
# Funciones matemáticas
import numpy as n
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
#definición del sistema
num=[1., 2.75, (2/3)]
den=[1., 5.5, (2/3)]
ftla= tf(num, den)
print("Funcion de transferencia en LA de la planta: ")
print(ftla)
ftlc=feedback(ftla,1)
print("Funcion de transferencia en lazocerrado: ")
print(ftlc)
# Grafico de polos y ceros del sistema enlazo cerrado.
plt.figure(1, figsize=[7, 4])
pzmap(ftlc)
plt.xlabel("Real")
plt.ylabel("Imaginario")
plt.title("Plano complejo. Polos del sistema en LC")
plt.show(block=False)
# Respuesta escalón del sistema en LA y LC
plt.figure(2, figsize=[6,4])
yout, T = step(ftla, T=25)
yout1, T1 = step(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel("tiempo (s)")
plt.ylabel("$y(t)$")
plt.title("Respuesta escalón sistema en LA y LC")
plt.grid()
# Respuesta escalón del sistema en LA y LC
plt.figure(3, figsize=[6, 4])
yout, T = impulse(ftla, T=25)
yout1, T1 = impulse(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel("tiempo (s)")
plt.ylabel("$y(t)$")
plt.title("Respuesta impulso sistema en LA y LC")
plt.grid()
plt.show()
# Out:
# Funcion de transferencia en LA de la planta:
# <TransferFunction>: sys[11]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 + 2.75 s + 0.6667
# ---------------------
# s^2 + 5.5 s + 0.6667
#
# Funcion de transferencia en lazocerrado:
# <TransferFunction>: sys[13]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 + 2.75 s + 0.6667
# ----------------------
# 2 s^2 + 8.25 s + 1.333
# /usr/local/lib/python3.10/dist-packages/control/pzmap.py:318: FutureWarning: pole_zero_plot() return value of poles, zeros is deprecated; use pole_zero_map()
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/control/timeresp.py:1975: UserWarning: System has direct feedthrough: ``D != 0``. The infinite impulse at ``t=0`` does not appear in the output.
# Results may be meaningless!
#   warnings.warn("System has direct feedthrough: ``D != 0``. The "

# %% [markdown]
# CIRCUITO RC

# %%
# Funciones matemáticas
import numpy as n
# Funciones para graficos
import matplotlib.pyplot as plt
# Funciones parecidas a Matlab
from control.matlab import *
#definición del sistema
num=[1.,(260/243),(125/729)]
den=[1.,(215/162),(125/729)]
ftla= tf(num, den)
print("Funcion de transferencia en LA de la planta: ")
print(ftla)
ftlc=feedback(ftla,1)
print("Funcion de transferencia en lazocerrado: ")
print(ftlc)
# Grafico de polos y ceros del sistema enlazo cerrado.
plt.figure(1, figsize=[7, 4])
pzmap(ftlc)
plt.xlabel("Real")
plt.ylabel("Imaginario")
plt.title("Plano complejo. Polos del sistema en LC")
plt.show(block=False)
# Respuesta escalón del sistema en LA y LC
plt.figure(2, figsize=[6, 4])
yout, T = step(ftla, T=25)
yout1, T1 = step(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel("tiempo (s)")
plt.ylabel("$y(t)$")
plt.title("Respuesta escalón sistema en LA y LC")
plt.grid()
# Respuesta escalón del sistema en LA y LC
plt.figure(3, figsize=[6, 4])
yout, T = impulse(ftla, T=25)
yout1, T1 = impulse(ftlc, T=25)
plt.plot(T.T, yout.T,T1.T,yout1.T)
plt.xlabel("tiempo (s)")
plt.ylabel("$y(t)$")
plt.title("Respuesta impulso sistema en LA y LC")
plt.grid()
plt.show()
# Out:
# Funcion de transferencia en LA de la planta:
# <TransferFunction>: sys[22]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# s^2 + 1.07 s + 0.1715
# ----------------------
# s^2 + 1.327 s + 0.1715
#
# Funcion de transferencia en lazocerrado:
# <TransferFunction>: sys[24]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#  s^2 + 1.07 s + 0.1715
# ------------------------
# 2 s^2 + 2.397 s + 0.3429
# /usr/local/lib/python3.10/dist-packages/control/pzmap.py:318: FutureWarning: pole_zero_plot() return value of poles, zeros is deprecated; use pole_zero_map()
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/control/timeresp.py:1975: UserWarning: System has direct feedthrough: ``D != 0``. The infinite impulse at ``t=0`` does not appear in the output.
# Results may be meaningless!
#   warnings.warn("System has direct feedthrough: ``D != 0``. The "
